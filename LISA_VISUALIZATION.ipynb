# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("C:/Users/Penti Anggraini/data bank.csv")

plt.scatter(data['age'], data['marital'])

plt.title("Scatter Plot")

plt.xlabel('Age')
plt.ylabel('Marital')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("C:/Users/Penti Anggraini/data bank.csv")

plt.plot(data['age'])
plt.plot(data['education'])

plt.title("Line Chart")

plt.xlabel('age')
plt.ylabel('education')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("C:/Users/Penti Anggraini/data bank.csv")

plt.bar(data['age'], data['housing'])

plt.title("Bar Chart")

plt.xlabel('Age')
plt.ylabel('Housing')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("C:/Users/Penti Anggraini/data bank.csv")

plt.hist(data['age'])

plt.title("Balance")

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("C:/Users/Penti Anggraini/data bank.csv")

bank = ['marital', 'education', 'housing']

data = [10, 9, 9]

plt.pie(data, labels=bank)

plt.title("bank data")

plt.show()
